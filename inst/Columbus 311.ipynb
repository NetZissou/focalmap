# %% [markdown]
# # Columbus 311 API demonstration

# %% [markdown]
# The City of Columbus makes its 311 data available via a set of [ArcGIS REST APIs](https://developers.arcgis.com/rest/services-reference/enterprise/get-started-with-the-services-directory.htm).
#
# The service root is available here: [http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer](http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer)
#
# There are two layers available from the service:
#   - [All Service Requests - Last 30 Days](http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0)
#   - [All Service Requests - Last 3 Years](http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/1)
#
# The following code demonstrates how to retrieve data for these two layers in [GeoJSON](https://en.wikipedia.org/wiki/GeoJSON) format using the REST APIs.
#
# The API limits the number of records returned to 1000 per request, therefore it is necessary to paginate the results.  The server does not allow pagination by number of records (this functionality exists, but has been disabled), however it is possible to subset the request by time period or geography.  Examples of both are included.

# %% [markdown]
# ## Import required libraries
#
# Note: Only ```requests``` and ```json``` are required to download the data.  If you only want to download data (and not visualize it), set ```VISUALIZE_DATA = False```.  If you want to display and save the data in CSV format, set ```TABULAR = True```

# %% [markdown]
# ## Import required libraries

# %% [markdown]
#   * If you only want to download data (and not visualize it), set ```VISUALIZE_DATA = False```
#   * If you want to display and save the data in CSV format, set ```TABULAR = True```

# %%
VISUALIZE_DATA = True
TABULAR = True

import requests
import json
import copy
import pandas as pd
#import pandas as gpd
from datetime import datetime,timedelta

if(VISUALIZE_DATA):
    from ipyleaflet import Map, GeoJSON
if(TABULAR):
    import geopandas as gpd

# %% [markdown]
# ## All Service Requests - Last 30 Days (no pagination)

# %% [markdown]
# Download data and save as a file.

# %%
params = {
    "where": "1=1",      # Download all records.  Do not filter by attribute.
    "outFields": "STATUS, SHAPE, OBJECTID, STATUS_DATE, DEPARTMENT_NAME, DIVISION_NAME, SECTION_NAME, DATAHUB_ID, CASE_ID, REPORTED_DATE, REQUEST_CATEGORY, REQUEST_SUBCATEGORY, REQUEST_TYPE, TEAM_NAME, STREET, CITY, ZIP, COLUMBUSCOMMUNITY, AREACOMMISSION, COUNCILDISTRICT, C1PRIORITYAREA, ZIPCODE, LOCATION_ID, LATITUDE, LONGITUDE, REQUEST_MODIFIED",    # Retrieve a subset of the attributes
    "f":"geojson"        # Download in GeoJSON format (other formats are probably not useful)
}    

baseUrl = "http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query"

r = requests.get(url=baseUrl, params=params)
data = r.json()
with open("columbus311_30days.geojson", "w") as f:
    f.write(json.dumps(data, indent=4))
#print(json.dumps(data, indent=4))

# %%
from datetime import date

today = date.today()
"columbus311_30days.geojson" + today.strftime("_%m_%d_%Y")
# Out:
# 'columbus311_30days.geojson_05_12_2022'

# %% [markdown]
# Visualize data as interactive map.

# %%
if(VISUALIZE_DATA):
    m = Map(
        center=(40, -83), 
        zoom=10
    )

    geo_json = GeoJSON(
        data=data,
        point_style={
            "radius": 2,
            "color": "blue",
            "fillColor": "blue",
            "fillOpacity": 1
        }
    )
    m.add_layer(geo_json)
else:
    m = "Visualization is disabled"

m
# Out:
# Map(center=[40, -83], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_te…

# %%
import geopandas as gpd
gpd.read_file("columbus311_30days.geojson")
# Out:
#        STATUS  OBJECTID   STATUS_DATE   DEPARTMENT_NAME  \
# 0      Closed    984321  1.649774e+12     Neighborhoods
# 1      Closed    984322  1.649774e+12      City Council
# 2      Closed    984323  1.649777e+12    Public Service
# 3    Received    984324           NaN     Public Safety
# 4    Received    984325           NaN     Public Safety
# ..        ...       ...           ...               ...
# 995    Closed    985556           NaN    Public Service
# 996    Closed    985558           NaN  Public Utilities
# 997    Closed    985559           NaN    Public Service
# 998    Closed    985560           NaN    Public Service
# 999    Closed    985561           NaN     Public Safety
#
#                      DIVISION_NAME                   SECTION_NAME  DATAHUB_ID  \
# 0               311 Service Center             311 Service Center     1353326
# 1               311 Service Center                   City Council     1353329
# 2               Street Maintenance             Street Maintenance     1353334
# 3    Patrol Operations Subdivision  Patrol Operations Subdivision     1353340
# 4    Patrol Operations Subdivision  Patrol Operations Subdivision     1353342
# ..                             ...                            ...         ...
# 995         Refuse Operations (AC)              Refuse Operations     1355357
# 996              Sewers and Drains              Sewers and Drains     1355359
# 997             Street Maintenance             Street Maintenance     1355360
# 998              Refuse Operations      Solid Waste Investigation     1355361
# 999                Wellness Bureau  Support Services Subdivisions     1355362
#
#                 CASE_ID  REPORTED_DATE     REQUEST_CATEGORY  ...  \
# 0    CAS-1525541-Z2L3W9  1649746201000           City Staff  ...
# 1    CAS-1525543-M5V6B0  1649747022000    Elected Officials  ...
# 2    CAS-1525547-B6D4H2  1649747789000  Streets and Traffic  ...
# 3    CAS-1525553-V5Y9T1  1649748810000        Public Safety  ...
# 4    CAS-1525555-B4W0Y8  1649748995000        Public Safety  ...
# ..                  ...            ...                  ...  ...
# 995  CAS-1527666-Q0S6B7  1649804084000               Refuse  ...
# 996  CAS-1527968-R7M0S0  1649804409000                Water  ...
# 997  CAS-1527984-J4S4K5  1649804414000               Refuse  ...
# 998  CAS-1527726-G0T8D6  1649804168000               Refuse  ...
# 999  CAS-1527746-Y7S5R5  1649804171000        Public Safety  ...
#
#        COLUMBUSCOMMUNITY                      AREACOMMISSION COUNCILDISTRICT  \
# 0
# 1               Downtown                                          District 7
# 2              Northland                                          District 5
# 3               Downtown                                          District 7
# 4              Near East           Near East Area Commission      District 7
# ..                   ...                                 ...             ...
# 995           South Side  Columbus Southside Area Commission      District 7
# 996            Northland                                          District 1
# 997            Northland                                          District 5
# 998  University District          University Area Commission      District 3
# 999            Northland                                          District 4
#
#     C1PRIORITYAREA ZIPCODE LOCATION_ID   LATITUDE  LONGITUDE REQUEST_MODIFIED  \
# 0                                 None        NaN        NaN    1649774099000
# 1                    43215     1642620  39.966168 -83.008447    1649774177000
# 2                    43231      211241  40.065116 -82.932890    1649776632000
# 3                    43215     1318333  39.965547 -82.993939    1649748827000
# 4        Near East   43203       27147  39.976299 -82.958432    1649749012000
# ..             ...     ...         ...        ...        ...              ...
# 995     Near South   43206        2747  39.944878 -82.976149    1649804105000
# 996                  43229      165010  40.103844 -82.969022    1649810689000
# 997                  43231      937129  40.088759 -82.939605    1649804428000
# 998                  43202      167379  40.013946 -83.008366    1649804177000
# 999                  43224      177439  40.056210 -82.986344    1649804182000
#
#                        geometry
# 0                          None
# 1    POINT (-83.00845 39.96617)
# 2    POINT (-82.93289 40.06512)
# 3    POINT (-82.99394 39.96555)
# 4    POINT (-82.95843 39.97630)
# ..                          ...
# 995  POINT (-82.97615 39.94488)
# 996  POINT (-82.96902 40.10384)
# 997  POINT (-82.93961 40.08876)
# 998  POINT (-83.00837 40.01395)
# 999  POINT (-82.98634 40.05621)
#
# [1000 rows x 26 columns]

# %%
gdf = gpd.read_file("columbus311_30days.geojson") 
gdf.to_csv("columbus311_30days.csv", index=False)
#gdf["DATE_OPEN"] = gdf["DATE_OPEN"].apply(lambda x:pd.to_datetime(x*1000000))
#gdf["STATUS_DATE"] = gdf["STATUS_DATE"].apply(lambda x:pd.to_datetime(x*1000000))
print("Number of records: {}".format(gdf.shape[0]))
#print("Earliest record: {}".format(gdf["DATE_OPEN"].min()))
#print("Earliest record: {}".format(gdf["DATE_OPEN"].max()))
gdf.head()
# Out:
# Number of records: 1000
#      STATUS  OBJECTID   STATUS_DATE DEPARTMENT_NAME  \
# 0    Closed    984321  1.649774e+12   Neighborhoods
# 1    Closed    984322  1.649774e+12    City Council
# 2    Closed    984323  1.649777e+12  Public Service
# 3  Received    984324           NaN   Public Safety
# 4  Received    984325           NaN   Public Safety
#
#                    DIVISION_NAME                   SECTION_NAME  DATAHUB_ID  \
# 0             311 Service Center             311 Service Center     1353326
# 1             311 Service Center                   City Council     1353329
# 2             Street Maintenance             Street Maintenance     1353334
# 3  Patrol Operations Subdivision  Patrol Operations Subdivision     1353340
# 4  Patrol Operations Subdivision  Patrol Operations Subdivision     1353342
#
#               CASE_ID  REPORTED_DATE     REQUEST_CATEGORY  ...  \
# 0  CAS-1525541-Z2L3W9  1649746201000           City Staff  ...
# 1  CAS-1525543-M5V6B0  1649747022000    Elected Officials  ...
# 2  CAS-1525547-B6D4H2  1649747789000  Streets and Traffic  ...
# 3  CAS-1525553-V5Y9T1  1649748810000        Public Safety  ...
# 4  CAS-1525555-B4W0Y8  1649748995000        Public Safety  ...
#
#   COLUMBUSCOMMUNITY             AREACOMMISSION COUNCILDISTRICT C1PRIORITYAREA  \
# 0
# 1          Downtown                                 District 7
# 2         Northland                                 District 5
# 3          Downtown                                 District 7
# 4         Near East  Near East Area Commission      District 7      Near East
#
#   ZIPCODE LOCATION_ID   LATITUDE  LONGITUDE REQUEST_MODIFIED  \
# 0                None        NaN        NaN    1649774099000
# 1   43215     1642620  39.966168 -83.008447    1649774177000
# 2   43231      211241  40.065116 -82.932890    1649776632000
# 3   43215     1318333  39.965547 -82.993939    1649748827000
# 4   43203       27147  39.976299 -82.958432    1649749012000
#
#                      geometry
# 0                        None
# 1  POINT (-83.00845 39.96617)
# 2  POINT (-82.93289 40.06512)
# 3  POINT (-82.99394 39.96555)
# 4  POINT (-82.95843 39.97630)
#
# [5 rows x 26 columns]

# %% [markdown]
# ## All Service Requests - Last 3 Years (no pagination)

# %% [markdown]
# Download data and save as a file.

# %%
params = {
    "where": "1=1",      # Download all records.  Do not filter by attribute.
    "outFields": "STATUS, SHAPE, OBJECTID, STATUS_DATE, DEPARTMENT_NAME, DIVISION_NAME, SECTION_NAME, DATAHUB_ID, CASE_ID, REPORTED_DATE, REQUEST_CATEGORY, REQUEST_SUBCATEGORY, REQUEST_TYPE, TEAM_NAME, STREET, CITY, ZIP, COLUMBUSCOMMUNITY, AREACOMMISSION, COUNCILDISTRICT, C1PRIORITYAREA, ZIPCODE, LOCATION_ID, LATITUDE, LONGITUDE, REQUEST_MODIFIED",    # Retrieve a subset of the attributes
    "f":"geojson"        # Download in GeoJSON format (other formats are probably not useful)
}    

baseUrl = "http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/1/query"

r = requests.get(url=baseUrl, params=params)
data = r.json()
with open("columbus311_3years.geojson", "w") as f:
    f.write(json.dumps(data, indent=4))
#print(json.dumps(data, indent=4))

# %% [markdown]
# Visualize data as interactive map.

# %%
if(VISUALIZE_DATA):
    m = Map(
        center=(40, -83), 
        zoom=10
    )

    geo_json = GeoJSON(
        data=data,
        point_style={
            "radius": 2,
            "color": "blue",
            "fillColor": "blue",
            "fillOpacity": 1
        }
    )
    m.add_layer(geo_json)
else:
    m = "Visualization is disabled"

m
# Out:
# Map(center=[40, -83], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_te…

# %%
gdf = gpd.read_file("columbus311_3years.geojson") 
gdf.to_csv("columbus311_3years.csv", index=False)
gdf["DATE_OPEN"] = gdf["DATE_OPEN"].apply(lambda x:pd.to_datetime(x*1000000))
gdf["STATUS_DATE"] = gdf["STATUS_DATE"].apply(lambda x:pd.to_datetime(x*1000000))
print("Number of records: {}".format(gdf.shape[0]))
print("Earliest record: {}".format(gdf["DATE_OPEN"].min()))
print("Earliest record: {}".format(gdf["DATE_OPEN"].max()))
gdf.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATE_OPEN'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-cb217df524cd> in <module>
#       1 gdf = gpd.read_file("columbus311_3years.geojson")
#       2 gdf.to_csv("columbus311_3years.csv", index=False)
# ----> 3 gdf["DATE_OPEN"] = gdf["DATE_OPEN"].apply(lambda x:pd.to_datetime(x*1000000))
#       4 gdf["STATUS_DATE"] = gdf["STATUS_DATE"].apply(lambda x:pd.to_datetime(x*1000000))
#       5 print("Number of records: {}".format(gdf.shape[0]))
#
# ~/.local/lib/python3.6/site-packages/geopandas/geodataframe.py in __getitem__(self, key)
#    1297         GeoDataFrame.
#    1298         """
# -> 1299         result = super(GeoDataFrame, self).__getitem__(key)
#    1300         geo_col = self._geometry_column_name
#    1301         if isinstance(result, Series) and isinstance(result.dtype, GeometryDtype):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'DATE_OPEN'

# %% [markdown]
# ## All Service Requests - Last 3 Years (pagination by time or geography)

# %% [markdown]
# First define some runtime parameters.

# %%
# Maximum number of records to retrieve from API per request
MAX_RECORDS = 1000

# Incrementally retrieve records between START_DATE and END_DATE (inclusive)
START_DATE = '2022-02-01'
END_DATE = '2022-02-28'

# If True, use spatial segmentation.  If False, use temporal segmentation
SPATIAL = False

# URL for Columbus 311 feature service (All Service Requests - Last 3 Years)
baseUrl = "http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query"

# %% [markdown]
# Next let's define some helper functions.

# %%
# Get the geographic extents (bounding box) of all requests opened between a start timestamp and end timestamp
def getExtents(start, end):
    params = {
        "where": "DATE_OPEN >= TIMESTAMP '{}' AND DATE_OPEN < TIMESTAMP '{}'".format(start.strftime("%Y-%m-%d"), end.strftime("%Y-%m-%d")),
        "f":"json",
        "returnExtentOnly": True
    }    

    r = requests.get(url=baseUrl, params=params)
    extent = r.json()['extent']
    return extent

# Get the record count of all requests opened between a start timestamp and end timestamp
def getSegmentCount(start, end):
    params = {
        "where": "DATE_OPEN >= TIMESTAMP '{}' AND DATE_OPEN < TIMESTAMP '{}'".format(start.strftime("%Y-%m-%d %H:%M:%S"), end.strftime("%Y-%m-%d %H:%M:%S")),
        "f":"json",
        "returnCountOnly": True,
    }    

    r = requests.get(url=baseUrl, params=params)
    return int(r.json()['count'])

# Get the spatial and attribute data for all requests opened between a start timestamp and end timestamp
# NOTE: This will return a maximum of 1000 records.  You must ensure that the start and end times are selected
# such that the record count is no greater than 1000.
# Output is an array of GeoJSON features
def getSegmentData(start, end):
    params = {
        "where": "DATE_OPEN >= TIMESTAMP '{}' AND DATE_OPEN < TIMESTAMP '{}'".format(start.strftime("%Y-%m-%d %H:%M:%S"), end.strftime("%Y-%m-%d %H:%M:%S")),
        "f":"geojson",
        "outFields": "OBJECTID,SWR_TYPE,SR_CATEGORY",
    } 

    r = requests.get(url=baseUrl, params=params)
    return r.json()['features']

# Get the record count of all requests opened between a start timestamp and end timestamp AND within the specified
# geographic bounding box.
# bbox = [xmin, ymin, xmax, ymax]
# Bounding box coordinates are specified in the default coordinate reference system for the feature service,
# namely EPSG:3857 at the time of writing.
def getSegmentCountSpatial(start, end, bbox):
    params = {
        "where": "DATE_OPEN >= TIMESTAMP '{}' AND DATE_OPEN < TIMESTAMP '{}'".format(start.strftime("%Y-%m-%d"), end.strftime("%Y-%m-%d")),
        "f":"json",
        "returnCountOnly": True,
        "geometry": "{},{},{},{}".format(bbox[0],bbox[1],bbox[2],bbox[3]),
        "geometryType": "esriGeometryEnvelope",
        "spatialRel": "esriSpatialRelIntersects"
    }    

    r = requests.get(url=baseUrl, params=params)
    return int(r.json()['count'])

# Get the spatial and attribute data for all requests opened between a start timestamp and end timestamp AND within
# the specified geographic bounding box. 
# NOTE: This will return a maximum of 1000 records.  You must ensure that the start and end times are selected
# such that the record count is no greater than 1000.
# bbox = [xmin, ymin, xmax, ymax]
# Bounding box coordinates are specified in the default coordinate reference system for the feature service,
# namely EPSG:3857 at the time of writing.
# Output is an array of GeoJSON features
def getSegmentDataSpatial(start, end, bbox):
    params = {
        "where": "DATE_OPEN >= TIMESTAMP '{}' AND DATE_OPEN < TIMESTAMP '{}'".format(start.strftime("%Y-%m-%d"), end.strftime("%Y-%m-%d")),
        "f":"geojson",
        "outFields":"*",
        "geometry": "{},{},{},{}".format(bbox[0],bbox[1],bbox[2],bbox[3]),
        "geometryType": "esriGeometryEnvelope",
        "spatialRel": "esriSpatialRelIntersects"
    }    

    r = requests.get(url=baseUrl, params=params)
    
    return r.json()['features']

# %% [markdown]
# The following functions provide loops that decompose the time range or geographic bounding box into increasingly smaller slices until the all slices contain fewer than MAX_RECORDS, then iteratively retrieve the records in each slice and assemble them into a single feature array. Final array may contain duplicates due to boundary conditions. These will be removed in the next step.

# %%
# Spatial slices
def getIntervalFeaturesSpatial(start, end):

    extents = getExtents(start, end)

    # Start with a single segment that spans the entire x-range of the bounding box
    segments=[[extents['xmin'],extents['xmax']]]

    bbox = [extents['xmin'], extents['ymin'], extents['xmax'], extents['ymax']]

    # Continue to decompose the span into segments until the no segment has more than MAX_RECORDS
    iterations = 0
    maxExceeded=True
    while(maxExceeded):
        iterations += 1
        segmentCount = []
        maxExceeded=False

        # For each segment, get the record count within the segment
        for i in range(0, len(segments)):
            bbox = [segments[i][0], extents['ymin'], segments[i][1], extents['ymax']]
            segmentCount.append(getSegmentCountSpatial(start, end, bbox))
            #print(iterations, i, segmentCount[i], segments[i][0], segments[i][1])

        # Check whether the record count in any segment exceeds MAX_RECORDS.  If it does,
        # divide that segment into two slices by creating a new segment boundary at half
        # the x distance
        for i in range(0, len(segments)):
            if(segmentCount[i] > MAX_RECORDS):
                maxExceeded=True
                segments.insert(i+1, [(segments[i][1]+segments[i][0])/2 , segments[i][1]])
                segments[i][1] = segments[i+1][0]


    # Test for duplicate values
    #totalCount = getSegmentCountSpatial(start, start, bbox) 
    #segmentCountSeries= pd.Series(segmentCount)
    #iterativeCount = segmentCountSeries.sum()
    #if(iterativeCount != totalCount):
    #    print("WARNING: Feature count is {}.  Expected {}. Check for duplicates.".format(iterativeCount, totalCount))

    # Fetch the data for each segment and assemble into a single array
    features=[]
    for i in range(0, len(segments)):
        if segmentCount[i] != 0:
            bbox = [segments[i][0], extents['ymin'], segments[i][1], extents['ymax']]
            features += getSegmentDataSpatial(start, end, bbox)

    return features

# Temporal slices
def getIntervalFeatures(start, end):

     # Start with a single segment that spans the entire time range
    segments=[[start,end]]

    # Continue to decompose the span into segments until the no segment has more than MAX_RECORDS
    iterations = 0
    maxExceeded=True
    while(maxExceeded):
        iterations += 1
        segmentCount = []
        maxExceeded=False

        # For each segment, get the record count within the segment
        for i in range(0, len(segments)):
            segmentCount.append(getSegmentCount(segments[i][0], segments[i][1]))
            #print(iterations, i, segmentCount[i], segments[i][0], segments[i][1])

        # Check whether the record count in any segment exceeds MAX_RECORDS.  If it does,
        # divide that segment into two slices by creating a new segment boundary at half of 
        # the time span
        for i in range(0, len(segments)):
            if(segmentCount[i] > MAX_RECORDS):
                maxExceeded=True
                segments.insert(i+1, [segments[i][0]+(segments[i][1]-segments[i][0])/2 , segments[i][1]])
                segments[i][1] = segments[i+1][0]

    # Test for duplicate values
    #totalCount = getSegmentCount(start, end) 
    #segmentCountSeries= pd.Series(segmentCount)
    #iterativeCount = segmentCountSeries.sum()
    #if(iterativeCount != totalCount):
    #    print("WARNING: Feature count is {}.  Expected {}. Check for duplicates.".format(iterativeCount, totalCount))

    # Fetch the data for each segment and assemble into a single array
    features=[]
    for i in range(0, len(segments)):
        if segmentCount[i] != 0:
            features += getSegmentData(segments[i][0], segments[i][1])

    return features

# %% [markdown]
# Now run the loop!

# %%
startDateTimestamp = datetime.strptime(START_DATE, "%Y-%m-%d")
endDateTimestamp = datetime.strptime(END_DATE, "%Y-%m-%d") + timedelta(days=1)  # Increment by 1 day, so that we can use "less than" query
nDays = (endDateTimestamp-startDateTimestamp).days

features = []
for i in range(0, nDays):
    todayTimestamp = startDateTimestamp+timedelta(days=i)
    tomorrowTimestamp = startDateTimestamp + timedelta(days=i+1)
    print("Getting data for {}".format(todayTimestamp.strftime("%Y-%m-%d")))
    if SPATIAL:
        features += getIntervalFeaturesSpatial(todayTimestamp, tomorrowTimestamp)
    else:
        features += getIntervalFeatures(todayTimestamp, tomorrowTimestamp)
# Out:
# Getting data for 2022-02-01
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-01+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-02+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 87, 'geometry': {'type': 'Point', 'coordinates': [-82.94252671301213, 40.00130182178123]}, 'properties': {'OBJECTID': 87, 'SWR_TYPE': 'BED BUG ITEMS/SPECIAL COLLECTION', 'SR_CATEGORY': 'PUBLIC HEALTH'}}, {'type': 'Feature', 'id': 115, 'geometry': {'type': 'Point', 'coordinates': [-82.98321751807889, 40.12678400822214]}, 'properties': {'OBJECTID': 115, 'SWR_TYPE': 'REPLACE DAMAGED 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 116, 'geometry': {'type': 'Point', 'coordinates': [-82.98321751807889, 40.12678400822214]}, 'properties': {'OBJECTID': 116, 'SWR_TYPE': '64-GALLON NEEDS REPLACED', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 70, 'geometry': {'type': 'Point', 'coordinates': [-83.07163442000558, 40.12823222801113]}, 'properties': {'OBJECTID': 70, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 191, 'geometry': {'type': 'Point', 'coordinates': [-83.07748605115624, 39.949816973872444]}, 'properties': {'OBJECTID': 191, 'SWR_TYPE': 'RUMPKE/MISSED YARD WASTE', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 195, 'geometry': {'type': 'Point', 'coordinates': [-83.03860978547122, 40.11444329718876]}, 'properties': {'OBJECTID': 195, 'SWR_TYPE': 'REPAIR 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 203, 'geometry': {'type': 'Point', 'coordinates': [-83.07983956803035, 39.94546791581855]}, 'properties': {'OBJECTID': 203, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 208, 'geometry': {'type': 'Point', 'coordinates': [-83.08603757877478, 39.96271275636431]}, 'properties': {'OBJECTID': 208, 'SWR_TYPE': 'SWI/ILLEGAL MATERIALS AT THE CURB', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 222, 'geometry': {'type': 'Point', 'coordinates': [-82.95224365199819, 39.93510326302092]}, 'properties': {'OBJECTID': 222, 'SWR_TYPE': 'REPAIR 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 260, 'geometry': {'type': 'Point', 'coordinates': [-83.00766362433222, 40.02680964627071]}, 'properties': {'OBJECTID': 260, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 390, 'geometry': {'type': 'Point', 'coordinates': [-83.0599809638969, 40.060616865804654]}, 'properties': {'OBJECTID': 390, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 397, 'geometry': {'type': 'Point', 'coordinates': [-83.06078229257139, 39.94980192125173]}, 'properties': {'OBJECTID': 397, 'SWR_TYPE': '64-GALLON MISSED SERVICE', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 411, 'geometry': {'type': 'Point', 'coordinates': [-82.97021009242788, 40.02163177502148]}, 'properties': {'OBJECTID': 411, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 440, 'geometry': {'type': 'Point', 'coordinates': [-82.98855569646764, 39.93912864172273]}, 'properties': {'OBJECTID': 440, 'SWR_TYPE': '64-GALLON MISSING/STOLEN', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 441, 'geometry': {'type': 'Point', 'coordinates': [-82.98855569646764, 39.93912864172273]}, 'properties': {'OBJECTID': 441, 'SWR_TYPE': '64-GALLON MISSING/STOLEN', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 344, 'geometry': {'type': ' ...
# Getting data for 2022-02-02
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-02+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-03+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 9, 'geometry': {'type': 'Point', 'coordinates': [-83.02089640674528, 40.108155786312096]}, 'properties': {'OBJECTID': 9, 'SWR_TYPE': 'INSPECT RESTAURANT/FOOD ESTABLISHMENT', 'SR_CATEGORY': 'PUBLIC HEALTH'}}, {'type': 'Feature', 'id': 89, 'geometry': {'type': 'Point', 'coordinates': [-83.02347922578218, 39.953691874339434]}, 'properties': {'OBJECTID': 89, 'SWR_TYPE': 'SWI/ILLEGAL MATERIALS IN THE ALLEY', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 215, 'geometry': {'type': 'Point', 'coordinates': [-83.03110620461536, 39.951885798293546]}, 'properties': {'OBJECTID': 215, 'SWR_TYPE': '64-GALLON MISSING/STOLEN', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 124, 'geometry': {'type': 'Point', 'coordinates': [-83.06988450362876, 39.95757916863643]}, 'properties': {'OBJECTID': 124, 'SWR_TYPE': 'REPLACE DAMAGED 300-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 134, 'geometry': {'type': 'Point', 'coordinates': [-83.08873856040752, 40.12148290825527]}, 'properties': {'OBJECTID': 134, 'SWR_TYPE': 'FIRE HYDRANT REPAIRS', 'SR_CATEGORY': 'FIRE HYDRANT'}}, {'type': 'Feature', 'id': 135, 'geometry': {'type': 'Point', 'coordinates': [-83.16156214900133, 39.962679129480335]}, 'properties': {'OBJECTID': 135, 'SWR_TYPE': 'REPLACE DAMAGED 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 387, 'geometry': {'type': 'Point', 'coordinates': [-82.92428284228, 39.9796990192451]}, 'properties': {'OBJECTID': 387, 'SWR_TYPE': 'SWI/ILLEGAL MATERIALS AT THE CURB', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 409, 'geometry': {'type': 'Point', 'coordinates': [-82.99338525772568, 40.02799599295467]}, 'properties': {'OBJECTID': 409, 'SWR_TYPE': 'CODE/TRASH AND DEBRIS IN YARD', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 418, 'geometry': {'type': 'Point', 'coordinates': [-82.8035060034336, 39.869199718651316]}, 'properties': {'OBJECTID': 418, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 444, 'geometry': {'type': 'Point', 'coordinates': [-83.06958333354828, 40.11232093408751]}, 'properties': {'OBJECTID': 444, 'SWR_TYPE': 'FIRE HYDRANT REPAIRS', 'SR_CATEGORY': 'FIRE HYDRANT'}}, {'type': 'Feature', 'id': 343, 'geometry': {'type': 'Point', 'coordinates': [-82.97716425197788, 40.03599640299609]}, 'properties': {'OBJECTID': 343, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 364, 'geometry': {'type': 'Point', 'coordinates': [-83.08003943509624, 39.949757708893785]}, 'properties': {'OBJECTID': 364, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 540, 'geometry': {'type': 'Point', 'coordinates': [-83.08949844620467, 40.11202789565227]}, 'properties': {'OBJECTID': 540, 'SWR_TYPE': 'FIRE HYDRANT REPAIRS', 'SR_CATEGORY': 'FIRE HYDRANT'}}, {'type': 'Feature', 'id': 593, 'geometry': {'type': 'Point', 'coordinates': [-83.08896794701195, 40.12173476694662]}, 'properties': {'OBJECTID': 593, 'SWR_TYPE': 'FIRE HYDRANT REPAIRS', 'SR_CATEGORY': 'FIRE HYDRANT'}}, {'type': 'Feature', 'id': 638, 'geometry': {'type': 'Point', 'coordinates': [-82.98724698674428, 39.88352005279415]}, 'properties': {'OBJECTID': 638, 'SWR_TYPE': '64-GALLON MISSED SERVICE', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 484, 'geometry': {'type': 'Point', 'coordinates': [-83.17364198956129, 40.009933 ...
# Getting data for 2022-02-03
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-03+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-04+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 65, 'geometry': {'type': 'Point', 'coordinates': [-83.07724685225395, 39.946784681962704]}, 'properties': {'OBJECTID': 65, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 183, 'geometry': {'type': 'Point', 'coordinates': [-83.07539568496482, 39.9454870513091]}, 'properties': {'OBJECTID': 183, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 186, 'geometry': {'type': 'Point', 'coordinates': [-83.04512183915413, 39.94773720786802]}, 'properties': {'OBJECTID': 186, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 267, 'geometry': {'type': 'Point', 'coordinates': [-83.02414001752203, 39.951703565502044]}, 'properties': {'OBJECTID': 267, 'SWR_TYPE': 'CODE/TRASH AND DEBRIS IN YARD', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 468, 'geometry': {'type': 'Point', 'coordinates': [-82.9685210108604, 40.015426979974194]}, 'properties': {'OBJECTID': 468, 'SWR_TYPE': 'RAT COMPLAINT(OUTSIDE)', 'SR_CATEGORY': 'PUBLIC HEALTH'}}, {'type': 'Feature', 'id': 362, 'geometry': {'type': 'Point', 'coordinates': [-82.93182026087597, 40.05637394746751]}, 'properties': {'OBJECTID': 362, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 370, 'geometry': {'type': 'Point', 'coordinates': [-82.82531250005609, 39.925133395829945]}, 'properties': {'OBJECTID': 370, 'SWR_TYPE': 'REPLACE MISSING/STOLEN 90-GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 520, 'geometry': {'type': 'Point', 'coordinates': [-82.81369088652929, 39.91927384852615]}, 'properties': {'OBJECTID': 520, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 573, 'geometry': {'type': 'Point', 'coordinates': [-83.06992157081231, 39.9577491917985]}, 'properties': {'OBJECTID': 573, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 621, 'geometry': {'type': 'Point', 'coordinates': [-83.12410692916256, 39.90438757645725]}, 'properties': {'OBJECTID': 621, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 499, 'geometry': {'type': 'Point', 'coordinates': [-82.9718306864381, 39.87911197540496]}, 'properties': {'OBJECTID': 499, 'SWR_TYPE': 'SWI/CONTAINER LEFT AT COLLECTION POINT', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 753, 'geometry': {'type': 'Point', 'coordinates': [-82.92279005697513, 39.93371424113289]}, 'properties': {'OBJECTID': 753, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 788, 'geometry': {'type': 'Point', 'coordinates': [-82.9628445296306, 39.98206778114278]}, 'properties': {'OBJECTID': 788, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 703, 'geometry': {'type': 'Point', 'coordinates': [-83.02926915524924, 39.95121659969985]}, 'properties': {'OBJECTID': 703, 'SWR_TYPE': 'STREET TREE PLANTING', 'SR_CATEGORY': 'TREES'}}, {'type': 'Feature', 'id': 709, 'geometry': {'type': 'Point', 'coordinates': [-83.18035036465965, 40.0681236730432]}, 'properties': {'OBJECTID': 709, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 890, 'geometry': {'type': 'Point', 'coordinates': [-83.04190738858982, 39.925229997233 ...
# Getting data for 2022-02-04
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-04+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-05+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 2, 'geometry': {'type': 'Point', 'coordinates': [-83.08089773043446, 40.0240624512559]}, 'properties': {'OBJECTID': 2, 'SWR_TYPE': 'WATER LINE BREAK', 'SR_CATEGORY': 'WATER, SEWERS & DRAINS'}}, {'type': 'Feature', 'id': 100, 'geometry': {'type': 'Point', 'coordinates': [-82.84442287403319, 39.91223221873392]}, 'properties': {'OBJECTID': 100, 'SWR_TYPE': 'REPLACE MISSING/STOLEN 90-GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 50, 'geometry': {'type': 'Point', 'coordinates': [-83.00382460838851, 40.15058693328414]}, 'properties': {'OBJECTID': 50, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 51, 'geometry': {'type': 'Point', 'coordinates': [-83.00382460838851, 40.15058693328414]}, 'properties': {'OBJECTID': 51, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 210, 'geometry': {'type': 'Point', 'coordinates': [-82.84232071835197, 39.936826200115874]}, 'properties': {'OBJECTID': 210, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 271, 'geometry': {'type': 'Point', 'coordinates': [-83.03168958493391, 39.90393005689869]}, 'properties': {'OBJECTID': 271, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 272, 'geometry': {'type': 'Point', 'coordinates': [-83.03168958493391, 39.90393005689869]}, 'properties': {'OBJECTID': 272, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 292, 'geometry': {'type': 'Point', 'coordinates': [-82.96756952070135, 40.01763168284093]}, 'properties': {'OBJECTID': 292, 'SWR_TYPE': 'CODE/RODENT INFESTATION', 'SR_CATEGORY': 'PUBLIC HEALTH'}}, {'type': 'Feature', 'id': 295, 'geometry': {'type': 'Point', 'coordinates': [-82.9676101479084, 39.96780832189517]}, 'properties': {'OBJECTID': 295, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 393, 'geometry': {'type': 'Point', 'coordinates': [-83.07752886845594, 40.059266442239704]}, 'properties': {'OBJECTID': 393, 'SWR_TYPE': 'CODE/OCCUPIED STRUCTURE DANGEROUS OR IN DISREPAIR', 'SR_CATEGORY': 'CODE VIOLATIONS'}}, {'type': 'Feature', 'id': 368, 'geometry': {'type': 'Point', 'coordinates': [-82.90412371934464, 40.07324392325195]}, 'properties': {'OBJECTID': 368, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 557, 'geometry': {'type': 'Point', 'coordinates': [-82.95267798474313, 39.958096592176155]}, 'properties': {'OBJECTID': 557, 'SWR_TYPE': '7A TO 3P PARKING VIOLATIONS/CITY STREET', 'SR_CATEGORY': 'PARKING'}}, {'type': 'Feature', 'id': 559, 'geometry': {'type': 'Point', 'coordinates': [-82.95267798474313, 39.958096592176155]}, 'properties': {'OBJECTID': 559, 'SWR_TYPE': 'CODE/COMMERCIAL VEHICLE PARKED IN A RESIDENTIAL ZONE', 'SR_CATEGORY': 'CODE VIOLATIONS'}}, {'type': 'Feature', 'id': 649, 'geometry': {'type': 'Point', 'coordinates': [-83.06781445014255, 40.10742687822521]}, 'properties': {'OBJECTID': 649, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 654, 'geometry': {'type': 'Point', 'coordinates': [-82.93698273508335, 40.061338994985825]}, 'properties': {'OBJECTID': 654, 'SWR_TYPE': 'REPLACE DAMAGED 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 741, 'geometry': {'type': 'Point', 'coordinates': [-83.141160 ...
# Getting data for 2022-02-05
# Getting data for 2022-02-06
# Getting data for 2022-02-07
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-07+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-07+12%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 75, 'geometry': {'type': 'Point', 'coordinates': [-82.97853308145162, 40.038735948193164]}, 'properties': {'OBJECTID': 75, 'SWR_TYPE': '64-GALLON MISSED SERVICE', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 79, 'geometry': {'type': 'Point', 'coordinates': [-82.98212215913381, 40.13336006873112]}, 'properties': {'OBJECTID': 79, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 80, 'geometry': {'type': 'Point', 'coordinates': [-82.98212215913381, 40.13336006873112]}, 'properties': {'OBJECTID': 80, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 81, 'geometry': {'type': 'Point', 'coordinates': [-82.98212215913381, 40.13336006873112]}, 'properties': {'OBJECTID': 81, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 93, 'geometry': {'type': 'Point', 'coordinates': [-83.01152622105212, 40.14362355643834]}, 'properties': {'OBJECTID': 93, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 107, 'geometry': {'type': 'Point', 'coordinates': [-83.0040104168202, 40.15198600189528]}, 'properties': {'OBJECTID': 107, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 36, 'geometry': {'type': 'Point', 'coordinates': [-83.01037227937412, 40.144426698650655]}, 'properties': {'OBJECTID': 36, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 41, 'geometry': {'type': 'Point', 'coordinates': [-83.08134688448324, 39.95340511892828]}, 'properties': {'OBJECTID': 41, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 66, 'geometry': {'type': 'Point', 'coordinates': [-83.0091858573104, 40.141593166875936]}, 'properties': {'OBJECTID': 66, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 173, 'geometry': {'type': 'Point', 'coordinates': [-83.00489936896412, 40.15127936533694]}, 'properties': {'OBJECTID': 173, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 174, 'geometry': {'type': 'Point', 'coordinates': [-83.00489936896412, 40.15127936533694]}, 'properties': {'OBJECTID': 174, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 181, 'geometry': {'type': 'Point', 'coordinates': [-83.00898656696295, 40.14392499708294]}, 'properties': {'OBJECTID': 181, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 192, 'geometry': {'type': 'Point', 'coordinates': [-83.00896280023547, 40.14409803552611]}, 'properties': {'OBJECTID': 192, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 194, 'geometry': {'type': 'Point', 'coordinates': [-83.00506053121765, 40.14707226087942]}, 'properties': {'OBJECTID': 194, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 221, 'geometry': {'type': 'Point', 'coordinates': [-83.14148218560882, 40.00730946915533]}, 'properties': {'OBJECTID': 221, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 227, 'geometry': {'type': 'Point', 'coordinates': [-83.05499572549844, 40.06087384989231]}, 'properties': {'OBJECTID': 227, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_ ...
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-07+12%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-08+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 29, 'geometry': {'type': 'Point', 'coordinates': [-83.09231455143266, 40.09689627142935]}, 'properties': {'OBJECTID': 29, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 30, 'geometry': {'type': 'Point', 'coordinates': [-83.09609560088772, 40.108127713107706]}, 'properties': {'OBJECTID': 30, 'SWR_TYPE': 'SEWER/MISCELLANEOUS', 'SR_CATEGORY': 'WATER, SEWERS & DRAINS'}}, {'type': 'Feature', 'id': 35, 'geometry': {'type': 'Point', 'coordinates': [-83.01037227937412, 40.144426698650655]}, 'properties': {'OBJECTID': 35, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 265, 'geometry': {'type': 'Point', 'coordinates': [-82.7804795012305, 39.99942621513056]}, 'properties': {'OBJECTID': 265, 'SWR_TYPE': 'REPAIR 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 433, 'geometry': {'type': 'Point', 'coordinates': [-82.98764142081586, 39.88946190166586]}, 'properties': {'OBJECTID': 433, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 345, 'geometry': {'type': 'Point', 'coordinates': [-83.14785258305625, 39.94169147349525]}, 'properties': {'OBJECTID': 345, 'SWR_TYPE': '7A TO 3P PARKING VIOLATIONS/CITY STREET', 'SR_CATEGORY': 'PARKING'}}, {'type': 'Feature', 'id': 522, 'geometry': {'type': 'Point', 'coordinates': [-82.98362039990741, 39.9954023773459]}, 'properties': {'OBJECTID': 522, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 542, 'geometry': {'type': 'Point', 'coordinates': [-83.04378394047225, 40.05390154368543]}, 'properties': {'OBJECTID': 542, 'SWR_TYPE': 'POTHOLES', 'SR_CATEGORY': 'STREET MAINTENANCE'}}, {'type': 'Feature', 'id': 556, 'geometry': {'type': 'Point', 'coordinates': [-82.91182458101669, 40.028815372010314]}, 'properties': {'OBJECTID': 556, 'SWR_TYPE': 'STREET FLOODING/BLOCKED DRAINS', 'SR_CATEGORY': 'STREET MAINTENANCE'}}, {'type': 'Feature', 'id': 579, 'geometry': {'type': 'Point', 'coordinates': [-82.85117940511898, 39.97273647618185]}, 'properties': {'OBJECTID': 579, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 603, 'geometry': {'type': 'Point', 'coordinates': [-82.98740270880047, 40.04356931062403]}, 'properties': {'OBJECTID': 603, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 473, 'geometry': {'type': 'Point', 'coordinates': [-83.06235408201053, 40.12765940537623]}, 'properties': {'OBJECTID': 473, 'SWR_TYPE': 'REPAIR 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 733, 'geometry': {'type': 'Point', 'coordinates': [-82.97690181725247, 40.118461532765814]}, 'properties': {'OBJECTID': 733, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 758, 'geometry': {'type': 'Point', 'coordinates': [-83.09004315045699, 39.970645709805574]}, 'properties': {'OBJECTID': 758, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 808, 'geometry': {'type': 'Point', 'coordinates': [-82.86817388368262, 39.941261002745385]}, 'properties': {'OBJECTID': 808, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 907, 'geometry': {'type': 'Point', 'coordinates': [-82.99759439124453, 40.12136616068365]}, ...
# Getting data for 2022-02-08
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-08+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-09+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 24, 'geometry': {'type': 'Point', 'coordinates': [-82.94395547897994, 39.841205615924885]}, 'properties': {'OBJECTID': 24, 'SWR_TYPE': 'TRAFFIC SIGN/NEW SIGN/REMOVE/RELOCATE', 'SR_CATEGORY': 'TRAFFIC SIGNS'}}, {'type': 'Feature', 'id': 76, 'geometry': {'type': 'Point', 'coordinates': [-82.98212215913381, 40.13336006873112]}, 'properties': {'OBJECTID': 76, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 78, 'geometry': {'type': 'Point', 'coordinates': [-82.98212215913381, 40.13336006873112]}, 'properties': {'OBJECTID': 78, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 94, 'geometry': {'type': 'Point', 'coordinates': [-83.0442459161751, 40.03674242582743]}, 'properties': {'OBJECTID': 94, 'SWR_TYPE': 'REPAIR 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 72, 'geometry': {'type': 'Point', 'coordinates': [-83.00787256797572, 40.144541043025626]}, 'properties': {'OBJECTID': 72, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 284, 'geometry': {'type': 'Point', 'coordinates': [-82.955894548145, 39.968314751671265]}, 'properties': {'OBJECTID': 284, 'SWR_TYPE': 'DEAD ANIMAL COLLECTION FROM STREET', 'SR_CATEGORY': 'ANIMAL COMPLAINTS'}}, {'type': 'Feature', 'id': 287, 'geometry': {'type': 'Point', 'coordinates': [-82.9470711912198, 40.06791669223798]}, 'properties': {'OBJECTID': 287, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 304, 'geometry': {'type': 'Point', 'coordinates': [-82.9718156693015, 39.97470245637799]}, 'properties': {'OBJECTID': 304, 'SWR_TYPE': 'REPLACE MISSING/STOLEN 90-GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 153, 'geometry': {'type': 'Point', 'coordinates': [-83.01136101458317, 40.14449479577401]}, 'properties': {'OBJECTID': 153, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 457, 'geometry': {'type': 'Point', 'coordinates': [-82.91284246745501, 40.064928855877845]}, 'properties': {'OBJECTID': 457, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 458, 'geometry': {'type': 'Point', 'coordinates': [-82.95524221584019, 39.958279787768625]}, 'properties': {'OBJECTID': 458, 'SWR_TYPE': 'REPAIR 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 530, 'geometry': {'type': 'Point', 'coordinates': [-82.98477386368165, 40.055315499116155]}, 'properties': {'OBJECTID': 530, 'SWR_TYPE': 'REPLACE MISSING/STOLEN 90-GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 587, 'geometry': {'type': 'Point', 'coordinates': [-82.91295134596238, 40.00949363438587]}, 'properties': {'OBJECTID': 587, 'SWR_TYPE': 'REPAIR 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 590, 'geometry': {'type': 'Point', 'coordinates': [-83.0390983396284, 40.10465052492769]}, 'properties': {'OBJECTID': 590, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 482, 'geometry': {'type': 'Point', 'coordinates': [-82.99708678651515, 39.902127255773614]}, 'properties': {'OBJECTID': 482, 'SWR_TYPE': 'REPLACE DAMAGED 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 748, 'geometry': {'typ ...
# Getting data for 2022-02-09
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-09+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-10+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 74, 'geometry': {'type': 'Point', 'coordinates': [-83.09048105400515, 39.94908245404381]}, 'properties': {'OBJECTID': 74, 'SWR_TYPE': 'REPLACE DAMAGED 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 77, 'geometry': {'type': 'Point', 'coordinates': [-82.98212215913381, 40.13336006873112]}, 'properties': {'OBJECTID': 77, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 59, 'geometry': {'type': 'Point', 'coordinates': [-83.1408494365772, 40.00953376923708]}, 'properties': {'OBJECTID': 59, 'SWR_TYPE': '64-GALLON MISSED SERVICE', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 214, 'geometry': {'type': 'Point', 'coordinates': [-82.9832385952504, 39.997468308404336]}, 'properties': {'OBJECTID': 214, 'SWR_TYPE': 'CODE/TRASH AND DEBRIS IN YARD', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 220, 'geometry': {'type': 'Point', 'coordinates': [-82.94201350010042, 39.924634335891845]}, 'properties': {'OBJECTID': 220, 'SWR_TYPE': 'TRUCKS IN A PROHIBITED ZONE', 'SR_CATEGORY': 'LAW ENFORCEMENT'}}, {'type': 'Feature', 'id': 240, 'geometry': {'type': 'Point', 'coordinates': [-82.9700815120697, 40.03006256580927]}, 'properties': {'OBJECTID': 240, 'SWR_TYPE': 'CODE/DEAD OR UNSAFE TREE', 'SR_CATEGORY': 'TREES'}}, {'type': 'Feature', 'id': 242, 'geometry': {'type': 'Point', 'coordinates': [-83.13459573837001, 39.939707754229126]}, 'properties': {'OBJECTID': 242, 'SWR_TYPE': 'STREET TREE MAINTENANCE', 'SR_CATEGORY': 'TREES'}}, {'type': 'Feature', 'id': 245, 'geometry': {'type': 'Point', 'coordinates': [-83.11420015190244, 40.05841068585976]}, 'properties': {'OBJECTID': 245, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 258, 'geometry': {'type': 'Point', 'coordinates': [-82.97909971627496, 40.065462664497964]}, 'properties': {'OBJECTID': 258, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 139, 'geometry': {'type': 'Point', 'coordinates': [-83.07119886285693, 39.944755369288536]}, 'properties': {'OBJECTID': 139, 'SWR_TYPE': 'CODE/TRASH AND DEBRIS IN YARD', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 141, 'geometry': {'type': 'Point', 'coordinates': [-83.04794997192546, 39.94498430850954]}, 'properties': {'OBJECTID': 141, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 330, 'geometry': {'type': 'Point', 'coordinates': [-83.08296431103376, 39.946786608215874]}, 'properties': {'OBJECTID': 330, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 367, 'geometry': {'type': 'Point', 'coordinates': [-82.91647121833343, 39.935521230171325]}, 'properties': {'OBJECTID': 367, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 519, 'geometry': {'type': 'Point', 'coordinates': [-83.11019430623406, 40.019692197167146]}, 'properties': {'OBJECTID': 519, 'SWR_TYPE': '7A TO 3P PARKING VIOLATIONS/CITY STREET', 'SR_CATEGORY': 'PARKING'}}, {'type': 'Feature', 'id': 552, 'geometry': {'type': 'Point', 'coordinates': [-83.0467499951824, 39.92347282377211]}, 'properties': {'OBJECTID': 552, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 646, 'geometry': {'type': 'Point', 'coordinates': [-83.16905284352441, 39.93015037038908]}, 'properties':  ...
# Getting data for 2022-02-10
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-10+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-11+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 17, 'geometry': {'type': 'Point', 'coordinates': [-82.82366402952597, 39.86915218134409]}, 'properties': {'OBJECTID': 17, 'SWR_TYPE': 'POTHOLES', 'SR_CATEGORY': 'STREET MAINTENANCE'}}, {'type': 'Feature', 'id': 106, 'geometry': {'type': 'Point', 'coordinates': [-83.00871042304797, 40.13671047630439]}, 'properties': {'OBJECTID': 106, 'SWR_TYPE': 'REPLACE MISSING/STOLEN 90-GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 108, 'geometry': {'type': 'Point', 'coordinates': [-82.95785434061659, 39.929876572871585]}, 'properties': {'OBJECTID': 108, 'SWR_TYPE': 'BED BUG ITEMS/SPECIAL COLLECTION', 'SR_CATEGORY': 'PUBLIC HEALTH'}}, {'type': 'Feature', 'id': 64, 'geometry': {'type': 'Point', 'coordinates': [-83.14357763536643, 39.99656785514339]}, 'properties': {'OBJECTID': 64, 'SWR_TYPE': 'REPLACE DAMAGED 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 197, 'geometry': {'type': 'Point', 'coordinates': [-82.97022225112526, 39.95542393417602]}, 'properties': {'OBJECTID': 197, 'SWR_TYPE': 'SWI/ILLEGAL MATERIALS IN THE ALLEY', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 198, 'geometry': {'type': 'Point', 'coordinates': [-82.97022225112526, 39.95542393417602]}, 'properties': {'OBJECTID': 198, 'SWR_TYPE': 'SWI/ILLEGAL MATERIALS IN THE ALLEY', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 199, 'geometry': {'type': 'Point', 'coordinates': [-82.97022225112526, 39.95542393417602]}, 'properties': {'OBJECTID': 199, 'SWR_TYPE': '300-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 200, 'geometry': {'type': 'Point', 'coordinates': [-82.97022225112526, 39.95542393417602]}, 'properties': {'OBJECTID': 200, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 204, 'geometry': {'type': 'Point', 'coordinates': [-83.12041836485928, 39.91201815164869]}, 'properties': {'OBJECTID': 204, 'SWR_TYPE': 'REPLACE DAMAGED 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 231, 'geometry': {'type': 'Point', 'coordinates': [-82.96194522530135, 40.00781811832187]}, 'properties': {'OBJECTID': 231, 'SWR_TYPE': 'SWI/CONTAINER LEFT AT COLLECTION POINT', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 251, 'geometry': {'type': 'Point', 'coordinates': [-83.01378006086232, 40.04605928614687]}, 'properties': {'OBJECTID': 251, 'SWR_TYPE': 'TRAFFIC SIGN/NEW SIGN/REMOVE/RELOCATE', 'SR_CATEGORY': 'TRAFFIC SIGNS'}}, {'type': 'Feature', 'id': 259, 'geometry': {'type': 'Point', 'coordinates': [-82.961024508729, 40.00786291376965]}, 'properties': {'OBJECTID': 259, 'SWR_TYPE': 'SWI/CONTAINER LEFT AT COLLECTION POINT', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 391, 'geometry': {'type': 'Point', 'coordinates': [-82.92247829575746, 39.96984205686951]}, 'properties': {'OBJECTID': 391, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 428, 'geometry': {'type': 'Point', 'coordinates': [-83.14510332146857, 39.94622566751078]}, 'properties': {'OBJECTID': 428, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 352, 'geometry': {'type': 'Point', 'coordinates': [-82.97868428228698, 40.10104864292302]}, 'properties': {'OBJECTID': 352, 'SWR_TYPE': '64-GALLON MISSED SERVICE', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type':  ...
# Getting data for 2022-02-11
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-11+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-12+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 73, 'geometry': {'type': 'Point', 'coordinates': [-83.04738073468273, 39.99384752652684]}, 'properties': {'OBJECTID': 73, 'SWR_TYPE': 'REPAIR STREET AROUND MANHOLE', 'SR_CATEGORY': 'STREET MAINTENANCE'}}, {'type': 'Feature', 'id': 180, 'geometry': {'type': 'Point', 'coordinates': [-83.01237658965627, 40.144701251178134]}, 'properties': {'OBJECTID': 180, 'SWR_TYPE': 'REPAIR 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 184, 'geometry': {'type': 'Point', 'coordinates': [-83.07539568496482, 39.9454870513091]}, 'properties': {'OBJECTID': 184, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 239, 'geometry': {'type': 'Point', 'coordinates': [-83.06063431938284, 40.11196178583307]}, 'properties': {'OBJECTID': 239, 'SWR_TYPE': 'REPAIR 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 283, 'geometry': {'type': 'Point', 'coordinates': [-82.90711084673475, 39.953288045370925]}, 'properties': {'OBJECTID': 283, 'SWR_TYPE': 'CODE/DEAD OR UNSAFE TREE', 'SR_CATEGORY': 'TREES'}}, {'type': 'Feature', 'id': 286, 'geometry': {'type': 'Point', 'coordinates': [-82.9470711912198, 40.06791669223798]}, 'properties': {'OBJECTID': 286, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 323, 'geometry': {'type': 'Point', 'coordinates': [-82.83405600393904, 39.937165726530445]}, 'properties': {'OBJECTID': 323, 'SWR_TYPE': 'CODE/RODENT INFESTATION', 'SR_CATEGORY': 'PUBLIC HEALTH'}}, {'type': 'Feature', 'id': 383, 'geometry': {'type': 'Point', 'coordinates': [-82.98544241686557, 39.94765068602303]}, 'properties': {'OBJECTID': 383, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 384, 'geometry': {'type': 'Point', 'coordinates': [-83.07171069685468, 39.944975238971736]}, 'properties': {'OBJECTID': 384, 'SWR_TYPE': 'SWI/ILLEGAL MATERIALS IN THE ALLEY', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 399, 'geometry': {'type': 'Point', 'coordinates': [-82.91296126336313, 39.97318386020884]}, 'properties': {'OBJECTID': 399, 'SWR_TYPE': '64-GALLON NEEDS REPLACED', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 401, 'geometry': {'type': 'Point', 'coordinates': [-83.03804828002815, 39.988651265801586]}, 'properties': {'OBJECTID': 401, 'SWR_TYPE': 'REPLACE MISSING/STOLEN 90-GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 408, 'geometry': {'type': 'Point', 'coordinates': [-83.03285692318775, 39.89951038942405]}, 'properties': {'OBJECTID': 408, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 419, 'geometry': {'type': 'Point', 'coordinates': [-83.03928798027304, 39.98836007935439]}, 'properties': {'OBJECTID': 419, 'SWR_TYPE': 'POTHOLES', 'SR_CATEGORY': 'STREET MAINTENANCE'}}, {'type': 'Feature', 'id': 424, 'geometry': {'type': 'Point', 'coordinates': [-83.05148602924297, 39.901129042276686]}, 'properties': {'OBJECTID': 424, 'SWR_TYPE': 'SWI/CONTAINER LEFT AT COLLECTION POINT', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 373, 'geometry': {'type': 'Point', 'coordinates': [-83.06217869313782, 40.060691471216074]}, 'properties': {'OBJECTID': 373, 'SWR_TYPE': 'REPLACE DAMAGED 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 529, 'geometry': {'type': 'Point', 'coordinates': [-83.0591306770 ...
# Getting data for 2022-02-12
# Getting data for 2022-02-13
# Getting data for 2022-02-14
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-14+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-15+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 42, 'geometry': {'type': 'Point', 'coordinates': [-83.08134688448324, 39.95340511892828]}, 'properties': {'OBJECTID': 42, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 48, 'geometry': {'type': 'Point', 'coordinates': [-83.01064269293589, 40.1391306968738]}, 'properties': {'OBJECTID': 48, 'SWR_TYPE': 'REPLACE DAMAGED 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 172, 'geometry': {'type': 'Point', 'coordinates': [-83.00489936896412, 40.15127936533694]}, 'properties': {'OBJECTID': 172, 'SWR_TYPE': 'CONCERNS ABOUT SNOW REMOVAL', 'SR_CATEGORY': 'SNOW/ICE REMOVAL'}}, {'type': 'Feature', 'id': 193, 'geometry': {'type': 'Point', 'coordinates': [-83.01063392987031, 40.13829769107191]}, 'properties': {'OBJECTID': 193, 'SWR_TYPE': 'REPLACE DAMAGED 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 202, 'geometry': {'type': 'Point', 'coordinates': [-83.07983956803035, 39.94546791581855]}, 'properties': {'OBJECTID': 202, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 226, 'geometry': {'type': 'Point', 'coordinates': [-83.0800949114549, 39.92649161799846]}, 'properties': {'OBJECTID': 226, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 255, 'geometry': {'type': 'Point', 'coordinates': [-82.9631296333422, 39.90386678769116]}, 'properties': {'OBJECTID': 255, 'SWR_TYPE': 'CODE/TRASH AND DEBRIS IN YARD', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 261, 'geometry': {'type': 'Point', 'coordinates': [-82.97884343321262, 39.96879931140127]}, 'properties': {'OBJECTID': 261, 'SWR_TYPE': 'CODE/VACANT STRUCTURE DANGEROUS OR IN DISREPAIR', 'SR_CATEGORY': 'CODE VIOLATIONS'}}, {'type': 'Feature', 'id': 266, 'geometry': {'type': 'Point', 'coordinates': [-82.92300059512827, 39.996440768082266]}, 'properties': {'OBJECTID': 266, 'SWR_TYPE': 'POTHOLES', 'SR_CATEGORY': 'STREET MAINTENANCE'}}, {'type': 'Feature', 'id': 125, 'geometry': {'type': 'Point', 'coordinates': [-82.9065033762952, 39.96651917155867]}, 'properties': {'OBJECTID': 125, 'SWR_TYPE': 'REPLACE MISSING/STOLEN 90-GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 131, 'geometry': {'type': 'Point', 'coordinates': [-83.04357945426918, 40.02141394257885]}, 'properties': {'OBJECTID': 131, 'SWR_TYPE': 'REPLACE MISSING/STOLEN 90-GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 140, 'geometry': {'type': 'Point', 'coordinates': [-82.98742384166754, 40.0562406143871]}, 'properties': {'OBJECTID': 140, 'SWR_TYPE': '7A TO 3P SPEEDING IN A RESIDENTIAL AREA', 'SR_CATEGORY': 'LAW ENFORCEMENT'}}, {'type': 'Feature', 'id': 310, 'geometry': {'type': 'Point', 'coordinates': [-83.06896140652088, 39.95332308234578]}, 'properties': {'OBJECTID': 310, 'SWR_TYPE': '300-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 381, 'geometry': {'type': 'Point', 'coordinates': [-82.98342845149075, 39.93347176058852]}, 'properties': {'OBJECTID': 381, 'SWR_TYPE': 'CODE/OCCUPIED STRUCTURE DANGEROUS OR IN DISREPAIR', 'SR_CATEGORY': 'CODE VIOLATIONS'}}, {'type': 'Feature', 'id': 395, 'geometry': {'type': 'Point', 'coordinates': [-83.06078229257139, 39.94980192125173]}, 'properties': {'OBJECTID': 395, 'SWR_TYPE': '64-GALLON MISSING/STOLEN', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 396, ' ...
# Getting data for 2022-02-15
# ...
# Getting data for 2022-02-23
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-23+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-24+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 13, 'geometry': {'type': 'Point', 'coordinates': [-82.95078353392866, 40.08105826377182]}, 'properties': {'OBJECTID': 13, 'SWR_TYPE': 'FIRE HYDRANT REPAIRS', 'SR_CATEGORY': 'FIRE HYDRANT'}}, {'type': 'Feature', 'id': 90, 'geometry': {'type': 'Point', 'coordinates': [-83.00767136062345, 40.141960678016005]}, 'properties': {'OBJECTID': 90, 'SWR_TYPE': 'SEND LETTER TO PURCHASE ADDITIONAL REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 91, 'geometry': {'type': 'Point', 'coordinates': [-83.00767136062345, 40.141960678016005]}, 'properties': {'OBJECTID': 91, 'SWR_TYPE': 'REPLACE MISSING/STOLEN 90-GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 58, 'geometry': {'type': 'Point', 'coordinates': [-83.1408494365772, 40.00953376923708]}, 'properties': {'OBJECTID': 58, 'SWR_TYPE': '64-GALLON MISSED SERVICE', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 256, 'geometry': {'type': 'Point', 'coordinates': [-82.86200693847735, 39.926069051074954]}, 'properties': {'OBJECTID': 256, 'SWR_TYPE': 'REPLACE MISSING/STOLEN 90-GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 278, 'geometry': {'type': 'Point', 'coordinates': [-82.99129177078696, 39.86566637653736]}, 'properties': {'OBJECTID': 278, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 294, 'geometry': {'type': 'Point', 'coordinates': [-83.06292117317803, 39.95713511574844]}, 'properties': {'OBJECTID': 294, 'SWR_TYPE': '64-GALLON MISSING/STOLEN', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 303, 'geometry': {'type': 'Point', 'coordinates': [-82.81146549097424, 39.868295655437265]}, 'properties': {'OBJECTID': 303, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 316, 'geometry': {'type': 'Point', 'coordinates': [-82.97849291148705, 39.974370709404106]}, 'properties': {'OBJECTID': 316, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 317, 'geometry': {'type': 'Point', 'coordinates': [-83.04240962049549, 39.948460788868765]}, 'properties': {'OBJECTID': 317, 'SWR_TYPE': 'SWI/ILLEGAL MATERIALS IN THE ALLEY', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 319, 'geometry': {'type': 'Point', 'coordinates': [-82.982652685276, 39.949833602820576]}, 'properties': {'OBJECTID': 319, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 394, 'geometry': {'type': 'Point', 'coordinates': [-83.00442414221251, 39.93909170269093]}, 'properties': {'OBJECTID': 394, 'SWR_TYPE': 'POTHOLES', 'SR_CATEGORY': 'STREET MAINTENANCE'}}, {'type': 'Feature', 'id': 415, 'geometry': {'type': 'Point', 'coordinates': [-82.99195910585533, 40.03233652460537]}, 'properties': {'OBJECTID': 415, 'SWR_TYPE': 'REPLACE A BURNT 90/60 GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 429, 'geometry': {'type': 'Point', 'coordinates': [-83.14510332146857, 39.94622566751078]}, 'properties': {'OBJECTID': 429, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 443, 'geometry': {'type': 'Point', 'coordinates': [-82.96157537183089, 39.950082684655996]}, 'properties': {'OBJECTID': 443, 'SWR_TYPE': 'CODE/TRASH AND DEBRIS IN YARD', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 449, 'geometry': {'type': 'Point', 'coordinates':  ...
# Getting data for 2022-02-24
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-24+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-25+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 71, 'geometry': {'type': 'Point', 'coordinates': [-83.11861934117913, 40.05481061383003]}, 'properties': {'OBJECTID': 71, 'SWR_TYPE': '64-GALLON MISSED SERVICE', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 219, 'geometry': {'type': 'Point', 'coordinates': [-82.98603268277077, 40.071322397586975]}, 'properties': {'OBJECTID': 219, 'SWR_TYPE': 'STREET TREE MAINTENANCE', 'SR_CATEGORY': 'TREES'}}, {'type': 'Feature', 'id': 254, 'geometry': {'type': 'Point', 'coordinates': [-82.9631296333422, 39.90386678769116]}, 'properties': {'OBJECTID': 254, 'SWR_TYPE': 'CODE/TRASH AND DEBRIS IN YARD', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 277, 'geometry': {'type': 'Point', 'coordinates': [-82.96178889867898, 39.949600188406166]}, 'properties': {'OBJECTID': 277, 'SWR_TYPE': 'TRASH/DEBRIS ALONG RIGHT-OF-WAY', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 291, 'geometry': {'type': 'Point', 'coordinates': [-83.11845480485337, 39.93289364025847]}, 'properties': {'OBJECTID': 291, 'SWR_TYPE': 'STREET FLOODING/BLOCKED DRAINS', 'SR_CATEGORY': 'STREET MAINTENANCE'}}, {'type': 'Feature', 'id': 293, 'geometry': {'type': 'Point', 'coordinates': [-82.78213235014931, 40.00826978359375]}, 'properties': {'OBJECTID': 293, 'SWR_TYPE': '64-GALLON MISSED SERVICE', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 296, 'geometry': {'type': 'Point', 'coordinates': [-82.97884243608264, 39.99816162600224]}, 'properties': {'OBJECTID': 296, 'SWR_TYPE': 'INSPECT TATTOO/BODY PIERCING ESTABLISHMENT', 'SR_CATEGORY': 'PUBLIC HEALTH'}}, {'type': 'Feature', 'id': 299, 'geometry': {'type': 'Point', 'coordinates': [-83.0281339784792, 39.95673134222872]}, 'properties': {'OBJECTID': 299, 'SWR_TYPE': 'BASKETBALL HOOP IN RIGHT-OF-WAY', 'SR_CATEGORY': 'SIDEWALKS / CURBS / RAMPS'}}, {'type': 'Feature', 'id': 132, 'geometry': {'type': 'Point', 'coordinates': [-83.0628359544986, 39.95336054944004]}, 'properties': {'OBJECTID': 132, 'SWR_TYPE': 'SWI/ILLEGAL MATERIALS AT THE CURB', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 136, 'geometry': {'type': 'Point', 'coordinates': [-83.16156214900133, 39.962679129480335]}, 'properties': {'OBJECTID': 136, 'SWR_TYPE': 'REPLACE DAMAGED 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 325, 'geometry': {'type': 'Point', 'coordinates': [-83.01711450389071, 40.03481712915613]}, 'properties': {'OBJECTID': 325, 'SWR_TYPE': 'CODE/TRASH AND DEBRIS IN YARD', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 388, 'geometry': {'type': 'Point', 'coordinates': [-82.98295204704779, 40.095867752128385]}, 'properties': {'OBJECTID': 388, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 425, 'geometry': {'type': 'Point', 'coordinates': [-82.8471835505132, 39.92226528300363]}, 'properties': {'OBJECTID': 425, 'SWR_TYPE': 'REPAIR 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 460, 'geometry': {'type': 'Point', 'coordinates': [-83.07414018784563, 39.920009206427245]}, 'properties': {'OBJECTID': 460, 'SWR_TYPE': 'ABANDONED VEHICLE ON STREET/R.O.W.', 'SR_CATEGORY': 'ABANDONED VEHICLES'}}, {'type': 'Feature', 'id': 462, 'geometry': {'type': 'Point', 'coordinates': [-82.952901608655, 39.908559918833554]}, 'properties': {'OBJECTID': 462, 'SWR_TYPE': 'REPLACE MISSING/STOLEN 90-GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 371, 'geometry ...
# Getting data for 2022-02-25
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-25+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-26+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 84, 'geometry': {'type': 'Point', 'coordinates': [-82.99426274197667, 40.01783257509952]}, 'properties': {'OBJECTID': 84, 'SWR_TYPE': '90-GALLON CONTAINER NEEDS SERVICED', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 85, 'geometry': {'type': 'Point', 'coordinates': [-82.99426274197667, 40.01783257509952]}, 'properties': {'OBJECTID': 85, 'SWR_TYPE': 'CODE/TRASH AND DEBRIS IN YARD', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 86, 'geometry': {'type': 'Point', 'coordinates': [-82.99426274197667, 40.01783257509952]}, 'properties': {'OBJECTID': 86, 'SWR_TYPE': 'SWI/ILLEGAL MATERIALS IN THE ALLEY', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 95, 'geometry': {'type': 'Point', 'coordinates': [-82.95658610987826, 39.94580372103378]}, 'properties': {'OBJECTID': 95, 'SWR_TYPE': 'TRAFFIC SIGN/HANDICAP SIGN REQUEST', 'SR_CATEGORY': 'TRAFFIC SIGNS'}}, {'type': 'Feature', 'id': 98, 'geometry': {'type': 'Point', 'coordinates': [-82.98857429069571, 40.02328624918756]}, 'properties': {'OBJECTID': 98, 'SWR_TYPE': 'CONDITION OF ALLEY', 'SR_CATEGORY': 'STREET MAINTENANCE'}}, {'type': 'Feature', 'id': 102, 'geometry': {'type': 'Point', 'coordinates': [-82.98160469449587, 39.94428814687884]}, 'properties': {'OBJECTID': 102, 'SWR_TYPE': 'REPLACE DAMAGED 300-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 175, 'geometry': {'type': 'Point', 'coordinates': [-83.00020061408954, 40.14909106572989]}, 'properties': {'OBJECTID': 175, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 189, 'geometry': {'type': 'Point', 'coordinates': [-82.84029023295908, 39.90944621089397]}, 'properties': {'OBJECTID': 189, 'SWR_TYPE': 'REPAIR OF STREET LIGHTING', 'SR_CATEGORY': 'STREET LIGHTING'}}, {'type': 'Feature', 'id': 190, 'geometry': {'type': 'Point', 'coordinates': [-83.07748605115624, 39.949816973872444]}, 'properties': {'OBJECTID': 190, 'SWR_TYPE': 'REPAIR 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 205, 'geometry': {'type': 'Point', 'coordinates': [-83.0355418411466, 39.949949453044084]}, 'properties': {'OBJECTID': 205, 'SWR_TYPE': 'SWI/ILLEGAL MATERIALS IN THE ALLEY', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 212, 'geometry': {'type': 'Point', 'coordinates': [-83.07703712438119, 39.95159533526377]}, 'properties': {'OBJECTID': 212, 'SWR_TYPE': 'BULK ITEMS NOT PICKED UP', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 213, 'geometry': {'type': 'Point', 'coordinates': [-83.07703712438119, 39.95159533526377]}, 'properties': {'OBJECTID': 213, 'SWR_TYPE': 'BULK ITEMS NOT PICKED UP', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 224, 'geometry': {'type': 'Point', 'coordinates': [-82.95020438826835, 39.94840063502058]}, 'properties': {'OBJECTID': 224, 'SWR_TYPE': 'NARCOTICS ACTIVITY INSIDE A BUILDING', 'SR_CATEGORY': 'LAW ENFORCEMENT'}}, {'type': 'Feature', 'id': 225, 'geometry': {'type': 'Point', 'coordinates': [-82.95020438826835, 39.94840063502058]}, 'properties': {'OBJECTID': 225, 'SWR_TYPE': 'CODE/TRASH AND DEBRIS IN YARD', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 228, 'geometry': {'type': 'Point', 'coordinates': [-83.06007150329776, 39.95100771809268]}, 'properties': {'OBJECTID': 228, 'SWR_TYPE': 'SWI/ILLEGAL MATERIALS IN THE ALLEY', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 230, 'geometry': {'type': 'Point', 'coordi ...
# Getting data for 2022-02-26
# http://maps2.columbus.gov/arcgis/rest/services/Applications/ServiceRequests/MapServer/0/query?where=DATE_OPEN+%3E%3D+TIMESTAMP+%272022-02-26+00%3A00%3A00%27+AND+DATE_OPEN+%3C+TIMESTAMP+%272022-02-27+00%3A00%3A00%27&f=geojson&outFields=OBJECTID%2CSWR_TYPE%2CSR_CATEGORY {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}, 'features': [{'type': 'Feature', 'id': 4478, 'geometry': {'type': 'Point', 'coordinates': [-82.99502955019139, 39.93365987209683]}, 'properties': {'OBJECTID': 4478, 'SWR_TYPE': '64-GALLON MISSING/STOLEN', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 3387, 'geometry': {'type': 'Point', 'coordinates': [-82.88809835498763, 39.91821364307715]}, 'properties': {'OBJECTID': 3387, 'SWR_TYPE': 'CODE/TRASH AND DEBRIS IN YARD', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 3745, 'geometry': {'type': 'Point', 'coordinates': [-83.06312933977883, 39.93792309009351]}, 'properties': {'OBJECTID': 3745, 'SWR_TYPE': 'REQUEST TO ADD A 300-GALLON CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 8588, 'geometry': {'type': 'Point', 'coordinates': [-82.97936670905214, 40.00134721743049]}, 'properties': {'OBJECTID': 8588, 'SWR_TYPE': 'CODE/TRASH AND DEBRIS IN YARD', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 10759, 'geometry': {'type': 'Point', 'coordinates': [-82.9998870625295, 40.02293393551781]}, 'properties': {'OBJECTID': 10759, 'SWR_TYPE': 'RUMPKE/MISSED YARD WASTE', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}, {'type': 'Feature', 'id': 9808, 'geometry': {'type': 'Point', 'coordinates': [-83.07385597346617, 39.940866147056305]}, 'properties': {'OBJECTID': 9808, 'SWR_TYPE': 'REPAIR 90-GALLON REFUSE CONTAINER', 'SR_CATEGORY': 'REFUSE / TRASH / LITTER'}}, {'type': 'Feature', 'id': 9388, 'geometry': {'type': 'Point', 'coordinates': [-82.998436597756, 40.12139590314552]}, 'properties': {'OBJECTID': 9388, 'SWR_TYPE': '64-GALLON MISSING/STOLEN', 'SR_CATEGORY': 'RECYCLING / YARD WASTE'}}]}
# Getting data for 2022-02-27
# Getting data for 2022-02-28

# %% [markdown]
# Read the features into a dataframe, do some cleanup, and write to a file

# %%
gdf = gpd.GeoDataFrame.from_features(features, crs="EPSG:3857")

# Drop duplicates present due to segment boundary conditions.
gdf.drop_duplicates(subset=["OBJECTID"], inplace=True)

# Convert timestamps to datetime objects
#gdf['DATE_OPEN'] = gdf['DATE_OPEN'].astype('datetime64[ms]')
#gdf['STATUS_DATE'] = gdf['STATUS_DATE'].astype('datetime64[ms]')

# Write the data into a GeoPackage (SQLite database)
tag = "{}-{}".format(startDateTimestamp.strftime("%Y%m%d"), endDateTimestamp.strftime("%Y%m%d"))
gdf.to_file("./columbus311-{}.gpkg".format(tag), driver="GPKG", layer=tag)

# %%
df = pd.DataFrame(gdf)
df.drop(columns=["geometry","OBJECTID"], inplace=True)
df.to_excel("30day.xlsx")

# %%
df
# Out:
#                     geometry  OBJECTID  \
# 0     POINT (-82.943 40.001)        87
# 1     POINT (-82.983 40.127)       115
# 2     POINT (-82.983 40.127)       116
# 3     POINT (-83.072 40.128)        70
# 4     POINT (-83.077 39.950)       191
# ...                      ...       ...
# 9188  POINT (-83.063 39.938)      3745
# 9189  POINT (-82.979 40.001)      8588
# 9190  POINT (-83.000 40.023)     10759
# 9191  POINT (-83.074 39.941)      9808
# 9192  POINT (-82.998 40.121)      9388
#
#                                         SWR_TYPE              SR_CATEGORY
# 0               BED BUG ITEMS/SPECIAL COLLECTION            PUBLIC HEALTH
# 1     REPLACE DAMAGED 90-GALLON REFUSE CONTAINER  REFUSE / TRASH / LITTER
# 2                       64-GALLON NEEDS REPLACED   RECYCLING / YARD WASTE
# 3             90-GALLON CONTAINER NEEDS SERVICED  REFUSE / TRASH / LITTER
# 4                       RUMPKE/MISSED YARD WASTE   RECYCLING / YARD WASTE
# ...                                          ...                      ...
# 9188       REQUEST TO ADD A 300-GALLON CONTAINER  REFUSE / TRASH / LITTER
# 9189               CODE/TRASH AND DEBRIS IN YARD  REFUSE / TRASH / LITTER
# 9190                    RUMPKE/MISSED YARD WASTE   RECYCLING / YARD WASTE
# 9191           REPAIR 90-GALLON REFUSE CONTAINER  REFUSE / TRASH / LITTER
# 9192                    64-GALLON MISSING/STOLEN   RECYCLING / YARD WASTE
#
# [9193 rows x 4 columns]
